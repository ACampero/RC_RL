# %%
# Set up 
import theory_template_071416 as tt

# %%
# Run to sync any changes you make in the modules
reload(tt)
# Out:
# explaining events []
# ___________________________________________________________________________________________________
# 1 hypotheses:
#
# InteractionSet:
#
# Class assignments:
# {}
# _______
# ___________________________________________________________________________________________________
#
# explaining events [('stepBack', 'DARKBLUE', 'BLACK')]
# ___________________________________________________________________________________________________
# 2 hypotheses:
#
# InteractionSet:
# stepBack c1 c1
#
# Class assignments:
# {'c1': ['DARKBLUE', 'BLACK']}
# _______
#
# InteractionSet:
# stepBack c1 c2
#
# Class assignments:
# {'c2': ['BLACK'], 'c1': ['DARKBLUE']}
# _______
# ___________________________________________________________________________________________________
#
# explaining events [('stepBack', 'DARKBLUE', 'BLACK')]
# ___________________________________________________________________________________________________
# 2 hypotheses:
#
# InteractionSet:
# stepBack c1 c1
#
# Class assignments:
# {'c1': ['DARKBLUE', 'BLACK']}
# _______
#
# InteractionSet:
# stepBack c1 c2
#
# Class assignments:
# {'c2': ['BLACK'], 'c1': ['DARKBLUE']}
# _______
# ___________________________________________________________________________________________________
#
# explaining events [('collectResource', 'DARKBLUE', 'RED'), ('killSprite', 'DARKBLUE', 'RED')]
# ___________________________________________________________________________________________________
# 3 hypotheses:
#
# InteractionSet:
# stepBack c1 c1 ['trap>0']
# collectResource c1 c2 ['trap>0']
# killSprite c1 c2 ['trap>0']
#
# Class assignments:
# {'c2': ['RED'], 'c1': ['DARKBLUE', 'BLACK']}
# _______
#
# InteractionSet:
# stepBack c1 c2
# collectResource c1 c1 ['trap>0']
# killSprite c1 c1 ['trap>0']
#
# Class assignments:
# {'c2': ['BLACK'], 'c1': ['DARKBLUE', 'RED']}
# _______
#
# InteractionSet:
# stepBack c1 c2
# collectResource c1 c3 ['trap>0']
# killSprite c1 c3 ['trap>0']
#
# Class assignments:
# {'c3': ['RED'], 'c2': ['BLACK'], 'c1': ['DARKBLUE']}
# _______
# ___________________________________________________________________________________________________
#
# explaining events [('stepBack', 'DARKBLUE', 'BLACK')]
# ___________________________________________________________________________________________________
# 3 hypotheses:
#
# InteractionSet:
# stepBack c1 c1 ['trap>0']
# collectResource c1 c2 ['trap>0']
# killSprite c1 c2 ['trap>0']
#
# Class assignments:
# {'c2': ['RED'], 'c1': ['DARKBLUE', 'BLACK']}
# _______
#
# InteractionSet:
# stepBack c1 c2
# collectResource c1 c1 ['trap>0']
# killSprite c1 c1 ['trap>0']
#
# Class assignments:
# {'c2': ['BLACK'], 'c1': ['DARKBLUE', 'RED']}
# _______
#
# InteractionSet:
# stepBack c1 c2
# collectResource c1 c3 ['trap>0']
# killSprite c1 c3 ['trap>0']
#
# Class assignments:
# {'c3': ['RED'], 'c2': ['BLACK'], 'c1': ['DARKBLUE']}
# _______
# ___________________________________________________________________________________________________
#
# explaining events [('bounceForward', 'DARKBLUE', 'ORANGE')]
# ___________________________________________________________________________________________________
# 4 hypotheses:
#
# InteractionSet:
# stepBack c1 c1 ['trap>0']
# collectResource c1 c2 ['trap>0']
# killSprite c1 c2 ['trap>0']
# bounceForward c1 c3 ['trap>0']
#
# Class assignments:
# {'c3': ['ORANGE'], 'c2': ['RED'], 'c1': ['DARKBLUE', 'BLACK']}
# _______
#
# InteractionSet:
# stepBack c1 c2
# collectResource c1 c1 ['trap>0']
# killSprite c1 c1 ['trap>0']
# bounceForward c1 c3 ['trap>0']
#
# Class assignments:
# {'c3': ['ORANGE'], 'c2': ['BLACK'], 'c1': ['DARKBLUE', 'RED']}
# _______
#
# InteractionSet:
# stepBack c1 c2
# collectResource c1 c3 ['trap>0']
# killSprite c1 c3 ['trap>0']
# bounceForward c1 c1 ['trap>0']
#
# Class assignments:
# {'c3': ['RED'], 'c2': ['BLACK'], 'c1': ['DARKBLUE', 'ORANGE']}
# _______
#
# InteractionSet:
# stepBack c1 c2
# collectResource c1 c3 ['trap>0']
# killSprite c1 c3 ['trap>0']
# bounceForward c1 c4 ['trap>0']
#
# Class assignments:
# {'c3': ['RED'], 'c2': ['BLACK'], 'c1': ['DARKBLUE'], 'c4': ['ORANGE']}
# _______
# ___________________________________________________________________________________________________
#
# explaining events [('bounceForward', 'DARKBLUE', 'PINK')]
# ___________________________________________________________________________________________________
# 9 hypotheses:
#
# InteractionSet:
# stepBack c1 c2
# collectResource c1 c1 ['trap>0']
# killSprite c1 c1 ['trap>0']
# bounceForward c1 c3 ['trap>0']
#
# Class assignments:
# {'c3': ['ORANGE', 'PINK'], 'c2': ['BLACK'], 'c1': ['DARKBLUE', 'RED']}
# _______
#
# InteractionSet:
# stepBack c1 c2
# collectResource c1 c3 ['trap>0']
# killSprite c1 c3 ['trap>0']
# bounceForward c1 c1 ['trap>0']
#
# Class assignments:
# {'c3': ['RED'], 'c2': ['BLACK'], 'c1': ['DARKBLUE', 'ORANGE', 'PINK']}
# _______
#
# InteractionSet:
# stepBack c1 c1 ['trap>0']
# collectResource c1 c2 ['trap>0']
# killSprite c1 c2 ['trap>0']
# bounceForward c1 c3 ['trap>0']
#
# Class assignments:
# {'c3': ['ORANGE', 'PINK'], 'c2': ['RED'], 'c1': ['DARKBLUE', 'BLACK']}
# _______
#
# InteractionSet:
# stepBack c1 c2
# collectResource c1 c3 ['trap>0']
# killSprite c1 c3 ['trap>0']
# bounceForward c1 c4 ['trap>0']
#
# Class assignments:
# {'c3': ['RED'], 'c2': ['BLACK'], 'c1': ['DARKBLUE'], 'c4': ['ORANGE', 'PINK']}
# _______
#
# InteractionSet:
# stepBack c1 c1 ['trap>0']
# collectResource c1 c2 ['trap>0']
# killSprite c1 c2 ['trap>0']
# bounceForward c1 c3 ['trap>0']
# bounceForward c1 c4 ['trap>0']
#
# Class assignments:
# {'c3': ['ORANGE'], 'c2': ['RED'], 'c1': ['DARKBLUE', 'BLACK'], 'c4': ['PINK']}
# _______
#
# InteractionSet:
# stepBack c1 c2
# collectResource c1 c1 ['trap>0']
# killSprite c1 c1 ['trap>0']
# bounceForward c1 c3 ['trap>0']
# bounceForward c1 c4 ['trap>0']
#
# Class assignments:
# {'c3': ['ORANGE'], 'c2': ['BLACK'], 'c1': ['DARKBLUE', 'RED'], 'c4': ['PINK']}
# _______
#
# InteractionSet:
# stepBack c1 c2
# collectResource c1 c3 ['trap>0']
# killSprite c1 c3 ['trap>0']
# bounceForward c1 c1 ['trap>0']
# bounceForward c1 c4 ['trap>0']
#
# Class assignments:
# {'c3': ['RED'], 'c2': ['BLACK'], 'c1': ['DARKBLUE', 'ORANGE'], 'c4': ['PINK']}
# _______
#
# InteractionSet:
# stepBack c1 c2
# collectResource c1 c3 ['trap>0']
# killSprite c1 c3 ['trap>0']
# bounceForward c1 c4 ['trap>0']
# bounceForward c1 c1 ['trap>0']
#
# Class assignments:
# {'c3': ['RED'], 'c2': ['BLACK'], 'c1': ['DARKBLUE', 'PINK'], 'c4': ['ORANGE']}
# _______
#
# InteractionSet:
# stepBack c1 c2
# collectResource c1 c3 ['trap>0']
# killSprite c1 c3 ['trap>0']
# bounceForward c1 c4 ['trap>0']
# bounceForward c1 c5 ['trap>0']
#
# Class assignments:
# {'c3': ['RED'], 'c2': ['BLACK'], 'c1': ['DARKBLUE'], 'c5': ['PINK'], 'c4': ['ORANGE']}
# _______
# ___________________________________________________________________________________________________
#
# explaining events [('bounceForward', 'DARKBLUE', 'ORANGE')]
# ___________________________________________________________________________________________________
# 9 hypotheses:
#
# InteractionSet:
# stepBack c1 c2
# collectResource c1 c1 ['trap>0']
# killSprite c1 c1 ['trap>0']
# bounceForward c1 c3 ['trap>0']
#
# Class assignments:
# {'c3': ['ORANGE', 'PINK'], 'c2': ['BLACK'], 'c1': ['DARKBLUE', 'RED']}
# _______
#
# InteractionSet:
# stepBack c1 c2
# collectResource c1 c3 ['trap>0']
# killSprite c1 c3 ['trap>0']
# bounceForward c1 c1 ['trap>0']
#
# Class assignments:
# {'c3': ['RED'], 'c2': ['BLACK'], 'c1': ['DARKBLUE', 'ORANGE', 'PINK']}
# _______
#
# InteractionSet:
# stepBack c1 c1 ['trap>0']
# collectResource c1 c2 ['trap>0']
# killSprite c1 c2 ['trap>0']
# bounceForward c1 c3 ['trap>0']
#
# Class assignments:
# {'c3': ['ORANGE', 'PINK'], 'c2': ['RED'], 'c1': ['DARKBLUE', 'BLACK']}
# _______
#
# InteractionSet:
# stepBack c1 c2
# collectResource c1 c3 ['trap>0']
# killSprite c1 c3 ['trap>0']
# bounceForward c1 c4 ['trap>0']
#
# Class assignments:
# {'c3': ['RED'], 'c2': ['BLACK'], 'c1': ['DARKBLUE'], 'c4': ['ORANGE', 'PINK']}
# _______
#
# InteractionSet:
# stepBack c1 c1 ['trap>0']
# collectResource c1 c2 ['trap>0']
# killSprite c1 c2 ['trap>0']
# bounceForward c1 c3 ['trap>0']
# bounceForward c1 c4 ['trap>0']
#
# Class assignments:
# {'c3': ['ORANGE'], 'c2': ['RED'], 'c1': ['DARKBLUE', 'BLACK'], 'c4': ['PINK']}
# _______
#
# InteractionSet:
# stepBack c1 c2
# collectResource c1 c1 ['trap>0']
# killSprite c1 c1 ['trap>0']
# bounceForward c1 c3 ['trap>0']
# bounceForward c1 c4 ['trap>0']
#
# Class assignments:
# {'c3': ['ORANGE'], 'c2': ['BLACK'], 'c1': ['DARKBLUE', 'RED'], 'c4': ['PINK']}
# _______
#
# InteractionSet:
# stepBack c1 c2
# collectResource c1 c3 ['trap>0']
# killSprite c1 c3 ['trap>0']
# bounceForward c1 c1 ['trap>0']
# bounceForward c1 c4 ['trap>0']
#
# Class assignments:
# {'c3': ['RED'], 'c2': ['BLACK'], 'c1': ['DARKBLUE', 'ORANGE'], 'c4': ['PINK']}
# _______
#
# InteractionSet:
# stepBack c1 c2
# collectResource c1 c3 ['trap>0']
# killSprite c1 c3 ['trap>0']
# bounceForward c1 c4 ['trap>0']
# bounceForward c1 c1 ['trap>0']
#
# Class assignments:
# {'c3': ['RED'], 'c2': ['BLACK'], 'c1': ['DARKBLUE', 'PINK'], 'c4': ['ORANGE']}
# _______
#
# InteractionSet:
# stepBack c1 c2
# collectResource c1 c3 ['trap>0']
# killSprite c1 c3 ['trap>0']
# bounceForward c1 c4 ['trap>0']
# bounceForward c1 c5 ['trap>0']
#
# Class assignments:
# {'c3': ['RED'], 'c2': ['BLACK'], 'c1': ['DARKBLUE'], 'c5': ['PINK'], 'c4': ['ORANGE']}
# _______
# ___________________________________________________________________________________________________
#
# explaining events [('killSprite', 'DARKBLUE', 'BLUE')]
# ___________________________________________________________________________________________________
# 11 hypotheses:
#
# InteractionSet:
# stepBack c1 c2
# collectResource c1 c3 ['trap>0']
# killSprite c1 c3 ['trap>0']
# bounceForward c1 c4 ['trap>0']
# killSprite c1 c1 ['trap>0']
#
# Class assignments:
# {'c3': ['RED'], 'c2': ['BLACK'], 'c1': ['DARKBLUE', 'BLUE'], 'c4': ['ORANGE', 'PINK']}
# _______
#
# InteractionSet:
# stepBack c1 c1 ['trap>0']
# collectResource c1 c2 ['trap>0']
# killSprite c1 c2 ['trap>0']
# bounceForward c1 c3 ['trap>0']
# killSprite c1 c4 ['trap>0']
#
# Class assignments:
# {'c3': ['ORANGE', 'PINK'], 'c2': ['RED'], 'c1': ['DARKBLUE', 'BLACK'], 'c4': ['BLUE']}
# _______
#
# InteractionSet:
# stepBack c1 c2
# collectResource c1 c1 ['trap>0']
# killSprite c1 c1 ['trap>0']
# bounceForward c1 c3 ['trap>0']
# killSprite c1 c4 ['trap>0']
#
# Class assignments:
# {'c3': ['ORANGE', 'PINK'], 'c2': ['BLACK'], 'c1': ['DARKBLUE', 'RED'], 'c4': ['BLUE']}
# _______
#
# InteractionSet:
# stepBack c1 c2
# collectResource c1 c3 ['trap>0']
# killSprite c1 c3 ['trap>0']
# bounceForward c1 c1 ['trap>0']
# killSprite c1 c4 ['trap>0']
#
# Class assignments:
# {'c3': ['RED'], 'c2': ['BLACK'], 'c1': ['DARKBLUE', 'ORANGE', 'PINK'], 'c4': ['BLUE']}
# _______
#
# InteractionSet:
# stepBack c1 c2
# collectResource c1 c3 ['trap>0']
# killSprite c1 c3 ['trap>0']
# bounceForward c1 c4 ['trap>0']
# killSprite c1 c5 ['trap>0']
#
# Class assignments:
# {'c3': ['RED'], 'c2': ['BLACK'], 'c1': ['DARKBLUE'], 'c5': ['BLUE'], 'c4': ['ORANGE', 'PINK']}
# _______
#
# InteractionSet:
# stepBack c1 c2
# collectResource c1 c3 ['trap>0']
# killSprite c1 c3 ['trap>0']
# bounceForward c1 c1 ['trap>0']
# bounceForward c1 c4 ['trap>0']
# killSprite c1 c5 ['trap>0']
#
# Class assignments:
# {'c3': ['RED'], 'c2': ['BLACK'], 'c1': ['DARKBLUE', 'ORANGE'], 'c5': ['BLUE'], 'c4': ['PINK']}
# _______
#
# InteractionSet:
# stepBack c1 c2
# collectResource c1 c1 ['trap>0']
# killSprite c1 c1 ['trap>0']
# bounceForward c1 c3 ['trap>0']
# bounceForward c1 c4 ['trap>0']
# killSprite c1 c5 ['trap>0']
#
# Class assignments:
# {'c3': ['ORANGE'], 'c2': ['BLACK'], 'c1': ['DARKBLUE', 'RED'], 'c5': ['BLUE'], 'c4': ['PINK']}
# _______
#
# InteractionSet:
# stepBack c1 c2
# collectResource c1 c3 ['trap>0']
# killSprite c1 c3 ['trap>0']
# bounceForward c1 c4 ['trap>0']
# bounceForward c1 c1 ['trap>0']
# killSprite c1 c5 ['trap>0']
#
# Class assignments:
# {'c3': ['RED'], 'c2': ['BLACK'], 'c1': ['DARKBLUE', 'PINK'], 'c5': ['BLUE'], 'c4': ['ORANGE']}
# _______
#
# InteractionSet:
# stepBack c1 c2
# collectResource c1 c3 ['trap>0']
# killSprite c1 c3 ['trap>0']
# bounceForward c1 c4 ['trap>0']
# bounceForward c1 c5 ['trap>0']
# killSprite c1 c1 ['trap>0']
#
# Class assignments:
# {'c3': ['RED'], 'c2': ['BLACK'], 'c1': ['DARKBLUE', 'BLUE'], 'c5': ['PINK'], 'c4': ['ORANGE']}
# _______
#
# InteractionSet:
# stepBack c1 c1 ['trap>0']
# collectResource c1 c2 ['trap>0']
# killSprite c1 c2 ['trap>0']
# bounceForward c1 c3 ['trap>0']
# bounceForward c1 c4 ['trap>0']
# killSprite c1 c5 ['trap>0']
#
# Class assignments:
# {'c3': ['ORANGE'], 'c2': ['RED'], 'c1': ['DARKBLUE', 'BLACK'], 'c5': ['BLUE'], 'c4': ['PINK']}
# _______
#
# InteractionSet:
# stepBack c1 c2
# collectResource c1 c3 ['trap>0']
# killSprite c1 c3 ['trap>0']
# bounceForward c1 c4 ['trap>0']
# bounceForward c1 c5 ['trap>0']
# killSprite c1 c6 ['trap>0']
#
# Class assignments:
# {'c3': ['RED'], 'c2': ['BLACK'], 'c1': ['DARKBLUE'], 'c6': ['BLUE'], 'c5': ['PINK'], 'c4': ['ORANGE']}
# _______
# ___________________________________________________________________________________________________
#
# explaining events [('collectResource', 'DARKBLUE', 'GREEN'), ('killSprite', 'DARKBLUE', 'GREEN')]
# ___________________________________________________________________________________________________
# 24 hypotheses:
#
# InteractionSet:
# stepBack c1 c2
# collectResource c1 c3 ['trap>0']
# killSprite c1 c3 ['trap>0']
# bounceForward c1 c4 ['trap>0']
# killSprite c1 c1 ['trap>0']
#
# Class assignments:
# {'c3': ['RED', 'GREEN'], 'c2': ['BLACK'], 'c1': ['DARKBLUE', 'BLUE'], 'c4': ['ORANGE', 'PINK']}
# _______
#
# InteractionSet:
# stepBack c1 c2
# collectResource c1 c3 ['trap>0']
# killSprite c1 c3 ['trap>0']
# bounceForward c1 c1 ['trap>0']
# killSprite c1 c4 ['trap>0', 'treasure>0']
# collectResource c1 c3 ['trap>0', 'treasure>0']
#
# Class assignments:
# {'c3': ['RED', 'GREEN'], 'c2': ['BLACK'], 'c1': ['DARKBLUE', 'ORANGE', 'PINK'], 'c4': ['BLUE']}
# _______
#
# InteractionSet:
# stepBack c1 c2
# collectResource c1 c1 ['trap>0']
# killSprite c1 c1 ['trap>0']
# bounceForward c1 c3 ['trap>0']
# killSprite c1 c4 ['trap>0', 'treasure>0']
# collectResource c1 c1 ['trap>0', 'treasure>0']
#
# Class assignments:
# {'c3': ['ORANGE', 'PINK'], 'c2': ['BLACK'], 'c1': ['DARKBLUE', 'RED', 'GREEN'], 'c4': ['BLUE']}
# _______
#
# InteractionSet:
# stepBack c1 c1 ['trap>0']
# collectResource c1 c2 ['trap>0']
# killSprite c1 c2 ['trap>0']
# bounceForward c1 c3 ['trap>0']
# killSprite c1 c4 ['trap>0', 'treasure>0']
# collectResource c1 c2 ['trap>0', 'treasure>0']
#
# Class assignments:
# {'c3': ['ORANGE', 'PINK'], 'c2': ['RED', 'GREEN'], 'c1': ['DARKBLUE', 'BLACK'], 'c4': ['BLUE']}
# _______
#
# InteractionSet:
# stepBack c1 c2
# collectResource c1 c3 ['trap>0']
# killSprite c1 c3 ['trap>0']
# bounceForward c1 c4 ['trap>0']
# killSprite c1 c5 ['trap>0', 'treasure>0']
# collectResource c1 c3 ['trap>0', 'treasure>0']
#
# Class assignments:
# {'c3': ['RED', 'GREEN'], 'c2': ['BLACK'], 'c1': ['DARKBLUE'], 'c5': ['BLUE'], 'c4': ['ORANGE', 'PINK']}
# _______
#
# InteractionSet:
# stepBack c1 c2
# collectResource c1 c3 ['trap>0']
# killSprite c1 c3 ['trap>0']
# bounceForward c1 c4 ['trap>0']
# bounceForward c1 c1 ['trap>0']
# killSprite c1 c5 ['treasure>0', 'trap>0']
# collectResource c1 c3 ['trap>0', 'treasure>0']
#
# Class assignments:
# {'c3': ['RED', 'GREEN'], 'c2': ['BLACK'], 'c1': ['DARKBLUE', 'PINK'], 'c5': ['BLUE'], 'c4': ['ORANGE']}
# _______
#
# InteractionSet:
# stepBack c1 c2
# collectResource c1 c3 ['trap>0']
# killSprite c1 c3 ['trap>0']
# bounceForward c1 c4 ['trap>0']
# killSprite c1 c1 ['trap>0']
# collectResource c1 c5 ['trap>0', 'treasure>0']
# killSprite c1 c5 ['trap>0', 'treasure>0']
#
# Class assignments:
# {'c3': ['RED'], 'c2': ['BLACK'], 'c1': ['DARKBLUE', 'BLUE'], 'c5': ['GREEN'], 'c4': ['ORANGE', 'PINK']}
# _______
#
# InteractionSet:
# stepBack c1 c1 ['trap>0']
# collectResource c1 c2 ['trap>0']
# killSprite c1 c2 ['trap>0']
# bounceForward c1 c3 ['trap>0']
# killSprite c1 c4 ['treasure>0', 'trap>0']
# collectResource c1 c5 ['trap>0', 'treasure>0']
# killSprite c1 c5 ['trap>0', 'treasure>0']
#
# Class assignments:
# {'c3': ['ORANGE', 'PINK'], 'c2': ['RED'], 'c1': ['DARKBLUE', 'BLACK'], 'c5': ['GREEN'], 'c4': ['BLUE']}
# _______
#
# InteractionSet:
# stepBack c1 c2
# collectResource c1 c3 ['trap>0']
# killSprite c1 c3 ['trap>0']
# bounceForward c1 c4 ['trap>0']
# killSprite c1 c5 ['treasure>0', 'trap>0']
# collectResource c1 c1 ['treasure>0', 'trap>0']
# killSprite c1 c1 ['trap>0', 'treasure>0']
#
# Class assignments:
# {'c3': ['RED'], 'c2': ['BLACK'], 'c1': ['DARKBLUE', 'GREEN'], 'c5': ['BLUE'], 'c4': ['ORANGE', 'PINK']}
# _______
#
# InteractionSet:
# stepBack c1 c2
# collectResource c1 c3 ['trap>0']
# killSprite c1 c3 ['trap>0']
# bounceForward c1 c1 ['trap>0']
# killSprite c1 c4 ['trap>0', 'treasure>0']
# collectResource c1 c5 ['treasure>0', 'trap>0']
# killSprite c1 c5 ['trap>0', 'treasure>0']
#
# Class assignments:
# {'c3': ['RED'], 'c2': ['BLACK'], 'c1': ['DARKBLUE', 'ORANGE', 'PINK'], 'c5': ['GREEN'], 'c4': ['BLUE']}
# _______
#
# InteractionSet:
# stepBack c1 c2
# collectResource c1 c3 ['trap>0']
# killSprite c1 c3 ['trap>0']
# bounceForward c1 c1 ['trap>0']
# bounceForward c1 c4 ['trap>0']
# killSprite c1 c5 ['treasure>0', 'trap>0']
# collectResource c1 c3 ['trap>0', 'treasure>0']
#
# Class assignments:
# {'c3': ['RED', 'GREEN'], 'c2': ['BLACK'], 'c1': ['DARKBLUE', 'ORANGE'], 'c5': ['BLUE'], 'c4': ['PINK']}
# _______
#
# InteractionSet:
# stepBack c1 c2
# collectResource c1 c1 ['trap>0']
# killSprite c1 c1 ['trap>0']
# bounceForward c1 c3 ['trap>0']
# bounceForward c1 c4 ['trap>0']
# killSprite c1 c5 ['trap>0', 'treasure>0']
# collectResource c1 c1 ['trap>0', 'treasure>0']
#
# Class assignments:
# {'c3': ['ORANGE'], 'c2': ['BLACK'], 'c1': ['DARKBLUE', 'RED', 'GREEN'], 'c5': ['BLUE'], 'c4': ['PINK']}
# _______
#
# InteractionSet:
# stepBack c1 c1 ['trap>0']
# collectResource c1 c2 ['trap>0']
# killSprite c1 c2 ['trap>0']
# bounceForward c1 c3 ['trap>0']
# bounceForward c1 c4 ['trap>0']
# killSprite c1 c5 ['treasure>0', 'trap>0']
# collectResource c1 c2 ['trap>0', 'treasure>0']
#
# Class assignments:
# {'c3': ['ORANGE'], 'c2': ['RED', 'GREEN'], 'c1': ['DARKBLUE', 'BLACK'], 'c5': ['BLUE'], 'c4': ['PINK']}
# _______
#
# InteractionSet:
# stepBack c1 c2
# collectResource c1 c1 ['trap>0']
# killSprite c1 c1 ['trap>0']
# bounceForward c1 c3 ['trap>0']
# killSprite c1 c4 ['trap>0', 'treasure>0']
# collectResource c1 c5 ['treasure>0', 'trap>0']
# killSprite c1 c5 ['trap>0', 'treasure>0']
#
# Class assignments:
# {'c3': ['ORANGE', 'PINK'], 'c2': ['BLACK'], 'c1': ['DARKBLUE', 'RED'], 'c5': ['GREEN'], 'c4': ['BLUE']}
# _______
#
# InteractionSet:
# stepBack c1 c2
# collectResource c1 c3 ['trap>0']
# killSprite c1 c3 ['trap>0']
# bounceForward c1 c4 ['trap>0']
# bounceForward c1 c5 ['trap>0']
# killSprite c1 c1 ['trap>0', 'treasure>0']
# collectResource c1 c3 ['trap>0', 'treasure>0']
#
# Class assignments:
# {'c3': ['RED', 'GREEN'], 'c2': ['BLACK'], 'c1': ['DARKBLUE', 'BLUE'], 'c5': ['PINK'], 'c4': ['ORANGE']}
# _______
#
# InteractionSet:
# stepBack c1 c2
# collectResource c1 c3 ['trap>0']
# killSprite c1 c3 ['trap>0']
# bounceForward c1 c4 ['trap>0']
# bounceForward c1 c5 ['trap>0']
# killSprite c1 c6 ['treasure>0', 'trap>0']
# collectResource c1 c3 ['trap>0', 'treasure>0']
#
# Class assignments:
# {'c3': ['RED', 'GREEN'], 'c2': ['BLACK'], 'c1': ['DARKBLUE'], 'c6': ['BLUE'], 'c5': ['PINK'], 'c4': ['ORANGE']}
# _______
#
# InteractionSet:
# stepBack c1 c2
# collectResource c1 c3 ['trap>0']
# killSprite c1 c3 ['trap>0']
# bounceForward c1 c4 ['trap>0']
# killSprite c1 c5 ['trap>0', 'treasure>0']
# collectResource c1 c6 ['trap>0', 'treasure>0']
# killSprite c1 c6 ['trap>0', 'treasure>0']
#
# Class assignments:
# {'c3': ['RED'], 'c2': ['BLACK'], 'c1': ['DARKBLUE'], 'c6': ['GREEN'], 'c5': ['BLUE'], 'c4': ['ORANGE', 'PINK']}
# _______
#
# InteractionSet:
# stepBack c1 c2
# collectResource c1 c1 ['trap>0']
# killSprite c1 c1 ['trap>0']
# bounceForward c1 c3 ['trap>0']
# bounceForward c1 c4 ['trap>0']
# killSprite c1 c5 ['trap>0', 'treasure>0']
# collectResource c1 c6 ['trap>0', 'treasure>0']
# killSprite c1 c6 ['trap>0', 'treasure>0']
#
# Class assignments:
# {'c3': ['ORANGE'], 'c2': ['BLACK'], 'c1': ['DARKBLUE', 'RED'], 'c6': ['GREEN'], 'c5': ['BLUE'], 'c4': ['PINK']}
# _______
#
# InteractionSet:
# stepBack c1 c2
# collectResource c1 c3 ['trap>0']
# killSprite c1 c3 ['trap>0']
# bounceForward c1 c4 ['trap>0']
# bounceForward c1 c5 ['trap>0']
# killSprite c1 c6 ['trap>0', 'treasure>0']
# collectResource c1 c1 ['trap>0', 'treasure>0']
# killSprite c1 c1 ['trap>0', 'treasure>0']
#
# Class assignments:
# {'c3': ['RED'], 'c2': ['BLACK'], 'c1': ['DARKBLUE', 'GREEN'], 'c6': ['BLUE'], 'c5': ['PINK'], 'c4': ['ORANGE']}
# _______
#
# InteractionSet:
# stepBack c1 c2
# collectResource c1 c3 ['trap>0']
# killSprite c1 c3 ['trap>0']
# bounceForward c1 c4 ['trap>0']
# bounceForward c1 c5 ['trap>0']
# killSprite c1 c1 ['trap>0', 'treasure>0']
# collectResource c1 c6 ['treasure>0', 'trap>0']
# killSprite c1 c6 ['trap>0', 'treasure>0']
#
# Class assignments:
# {'c3': ['RED'], 'c2': ['BLACK'], 'c1': ['DARKBLUE', 'BLUE'], 'c6': ['GREEN'], 'c5': ['PINK'], 'c4': ['ORANGE']}
# _______
#
# InteractionSet:
# stepBack c1 c2
# collectResource c1 c3 ['trap>0']
# killSprite c1 c3 ['trap>0']
# bounceForward c1 c4 ['trap>0']
# bounceForward c1 c1 ['trap>0']
# killSprite c1 c5 ['treasure>0', 'trap>0']
# collectResource c1 c6 ['treasure>0', 'trap>0']
# killSprite c1 c6 ['trap>0', 'treasure>0']
#
# Class assignments:
# {'c3': ['RED'], 'c2': ['BLACK'], 'c1': ['DARKBLUE', 'PINK'], 'c6': ['GREEN'], 'c5': ['BLUE'], 'c4': ['ORANGE']}
# _______
#
# InteractionSet:
# stepBack c1 c1 ['trap>0']
# collectResource c1 c2 ['trap>0']
# killSprite c1 c2 ['trap>0']
# bounceForward c1 c3 ['trap>0']
# bounceForward c1 c4 ['trap>0']
# killSprite c1 c5 ['trap>0', 'treasure>0']
# collectResource c1 c6 ['trap>0', 'treasure>0']
# killSprite c1 c6 ['trap>0', 'treasure>0']
#
# Class assignments:
# {'c3': ['ORANGE'], 'c2': ['RED'], 'c1': ['DARKBLUE', 'BLACK'], 'c6': ['GREEN'], 'c5': ['BLUE'], 'c4': ['PINK']}
# _______
#
# InteractionSet:
# stepBack c1 c2
# collectResource c1 c3 ['trap>0']
# killSprite c1 c3 ['trap>0']
# bounceForward c1 c1 ['trap>0']
# bounceForward c1 c4 ['trap>0']
# killSprite c1 c5 ['trap>0', 'treasure>0']
# collectResource c1 c6 ['trap>0', 'treasure>0']
# killSprite c1 c6 ['trap>0', 'treasure>0']
#
# Class assignments:
# {'c3': ['RED'], 'c2': ['BLACK'], 'c1': ['DARKBLUE', 'ORANGE'], 'c6': ['GREEN'], 'c5': ['BLUE'], 'c4': ['PINK']}
# _______
#
# InteractionSet:
# stepBack c1 c2
# collectResource c1 c3 ['trap>0']
# killSprite c1 c3 ['trap>0']
# bounceForward c1 c4 ['trap>0']
# bounceForward c1 c5 ['trap>0']
# killSprite c1 c6 ['trap>0', 'treasure>0']
# collectResource c1 c7 ['trap>0', 'treasure>0']
# killSprite c1 c7 ['trap>0', 'treasure>0']
#
# Class assignments:
# {'c3': ['RED'], 'c2': ['BLACK'], 'c1': ['DARKBLUE'], 'c7': ['GREEN'], 'c6': ['BLUE'], 'c5': ['PINK'], 'c4': ['ORANGE']}
# _______
# ___________________________________________________________________________________________________
# <module 'theory_template_071416' from 'theory_template_071416.pyc'>

# %%
# Testing new predicates encountered
# Testing grouping classes of objects together

'''
ISSUES:
- the second event adds a duplicate rule: killSprite c1 c2
- no hypotheses in final hypotheses set b/c the likelihood doesn't update from 0.0 to 1.0
'''
g1 = tt.Game()
trace = [{'agentAction': 'up', 'agentState': {}, 'effectList': [('bounceForward', 'DARKBLUE', 'ORANGE')]}, 
         {'agentAction': 'left', 'agentState': {}, 'effectList': [('bounceForward', 'DARKBLUE', 'PINK')]}]
timesteps = [tt.TimeStep(tr['agentAction'], tr['agentState'], tr['effectList']) for tr in trace]
hypotheses = tt.induction(g1, timesteps)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-0c46f7a9396e> in <module>()
#      10 trace = [{'agentAction': 'up', 'agentState': {}, 'effectList': [('bounceForward', 'DARKBLUE', 'ORANGE')]},
#      11          {'agentAction': 'left', 'agentState': {}, 'effectList': [('bounceForward', 'DARKBLUE', 'PINK')]}]
# ---> 12 timesteps = [TimeStep(tr['agentAction'], tr['agentState'], tr['effectList']) for tr in trace]
#      13 hypotheses = tt.induction(g1, timesteps)
#
# NameError: name 'TimeStep' is not defined

# %%
# Testing game termination events
'''
ISSUES:
- 'gameEnd' event is not supported in induction --> keeps recursing in self.generateHypotheses()

'''
g2 = tt.Game()

trace = [{'agentAction': 'right', 'agentState': {'medicine': 0}, 'effectList': [('killSprite', 'DARKBLUE', 'GOLD')]},
         {'agentAction': None, 'agentState': {'medicine': 0}, 'effectList': ['gameEnd']}]
timesteps = [tt.TimeStep(tr['agentAction'], tr['agentState'], tr['effectList']) for tr in trace]
#hypotheses = tt.induction(g2, timesteps)

# %%
# Testing preconditions 

'''
ISSUES:
- when no medicine, and runs into poison, doesn't print out killSprite event

'''

g3 = tt.Game()
trace = [{'agentAction': 'up', 'agentState': {'medicine': 1}, 'effectList': [('changeResource', 'DARKBLUE', 'WHITE', 1), ('killSprite', 'DARKBLUE', 'WHITE')]}, 
        {'agentAction': 'down', 'agentState': {'medicine': 0}, 'effectList': [('changeResource', 'DARKBLUE', 'WHITE', -1), ('killSprite', 'DARKBLUE', 'BROWN')]},
        ]
timesteps = [tt.TimeStep(tr['agentAction'], tr['agentState'], tr['effectList']) for tr in trace]
#hypotheses = tt.induction(g3, timesteps)

# %%
# Testing collecting / using resource
g4 = tt.Game()
trace = [{'agentAction': 'up', 'agentState': {'medicine': 1}, 'effectList': [('changeResource', 'DARKBLUE', 'WHITE', 1), ('killSprite', 'DARKBLUE', 'WHITE')]}, 
         {'agentAction': 'down', 'agentState': {'medicine': 0}, 'effectList': [('changeResource', 'DARKBLUE', 'WHITE', -1), ('killSprite', 'DARKBLUE', 'BROWN')]}]
timesteps = [tt.TimeStep(tr['agentAction'], tr['agentState'], tr['effectList']) for tr in trace]
#hypotheses = tt.induction(g4, timesteps)
