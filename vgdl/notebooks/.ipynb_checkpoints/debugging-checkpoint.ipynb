# %%
import sys
sys.path.insert(0, '../')

import itertools
import copy
import theory_template_071416 as tt

reload(tt)
# Out:
#   File "../theory_template_071416.py", line 262
#     print "\trelevantRules",rules_list"
#                                        ^
# IndentationError: unindent does not match any outer indentation level

# %%
## Debugging equality of theories
# g0 = tt.Game()
# t0 = tt.Theory(g0)
# t1 = tt.Theory(g0)

# i1 = tt.InteractionRule('killSprite', 'c1', 'c2')
# i2 = tt.InteractionRule('killSprite', 'c1', 'c2')
# i3 = tt.InteractionRule('killSprite', 'c2', 'c2')

# t0.classes = {'c1': ['BLACK'], 'c2': ['BLUE']}
# t0.interactionSet = [i1]
# t0.predicates = ['killSprite']

# t1.classes = {'c1': ['BLACK'], 'c2': ['BLUE']}
# t1.interactionSet = [i2]
# t1.predicates = ['killSprite']

# print "Theory equality:"
# print "Classes equal? {}".format(t0.classes == t1.classes)
# print "InteractionSet equal? {}".format(t0.interactionSet==t1.interactionSet)
# print "Predicates equal? {}".format(t0.predicates == t1.predicates)
# print "Equality overall?", t1==t0

# print "\n\nInteractionRule equality:"
# print "Tuple?", i1.asTuple()==i2.asTuple()
# print "Preconditions?", i1.preconditions==i2.preconditions
# print "Object type?", isinstance(i2, i1.__class__)
# print "Equality check?", i1==i2
# print "\n\n\n"

## Testing induction for equality -- DONE!
# g = tt.Game()
# rawTrace = [
# {'agentAction': 'up', 'agentState': {}, 'effectList': [('bounceForward', 'DARKBLUE', 'ORANGE')]}, 
# {'agentAction': 'up', 'agentState': {}, 'effectList': [('bounceForward', 'DARKBLUE', 'ORANGE'), ('undoAll', 'ORANGE', 'BLACK')]}, 
# {'agentAction': 'right', 'agentState': {}, 'effectList': [('bounceForward', 'DARKBLUE', 'ORANGE')]}, 
# {'agentAction': 'up', 'agentState': {}, 'effectList': [('changeResource', 'DARKBLUE', 'WHITE'), ('killSprite', 'DARKBLUE', 'WHITE')]}
# ]

# trace = [TimeStep(tr['agentAction'], tr['agentState'], tr['effectList']) for tr in rawTrace]
# hypotheses=list(g.induction(trace))

# %%
## Debugging preconditions
g = tt.Game()
rawTrace = [ 
{'agentAction': None, 'agentState': {}, 'effectList': [('killSprite', 'DARKBLUE', 'BLUE')]}, 
{'agentAction': None, 'agentState': {'trap': 1}, 'effectList': [('collectResource', 'DARKBLUE', 'RED'), ('killSprite', 'DARKBLUE', 'RED')]}, 
{'agentAction': None, 'agentState': {'trap': 1}, 'effectList': [('bounceForward', 'DARKBLUE', 'BLUE')]}, 
{'agentAction': None, 'agentState': {'trap': 1}, 'effectList': [('bounceForward', 'DARKBLUE', 'ORANGE')]}, 
{'agentAction': None, 'agentState': {'trap': 1}, 'effectList': [('killSprite', 'DARKBLUE', 'GOLD')]}
]

trace = [tt.TimeStep(tr['agentAction'], tr['agentState'], tr['effectList']) for tr in rawTrace]

hypotheses=list(g.induction(trace))
# Out:
# explaining events [('killSprite', 'DARKBLUE', 'BLUE')]
# ___________________________________________________________________
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# ****>>> events in timestep False| predictions False
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# ****>>> events in timestep False| predictions False
# Will add a rule.
# Going to clean hypothesis space!
# _______
#
# InteractionSet:
#
# Class assignments:
# {}
#
# (None, {}, [('killSprite', 'DARKBLUE', 'BLUE')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# ****>>> events in timestep False| predictions False
# -----> SUBTRACE (None, {}, [('killSprite', 'DARKBLUE', 'BLUE')]) | likelihood 0.0
#
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# ****>>> events in timestep False| predictions False
# _______
#
# InteractionSet:
# killSprite c1 c2
#
# Class assignments:
# {'c2': ['BLUE'], 'c1': ['DARKBLUE']}
#
# (None, {}, [('killSprite', 'DARKBLUE', 'BLUE')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2')]
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2')]
# -----> SUBTRACE (None, {}, [('killSprite', 'DARKBLUE', 'BLUE')]) | likelihood 1.0
#
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2')]
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2')]
# _______
#
# InteractionSet:
# killSprite c1 c1
#
# Class assignments:
# {'c1': ['DARKBLUE', 'BLUE']}
#
# (None, {}, [('killSprite', 'DARKBLUE', 'BLUE')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c1')]
# 	relevantRules [('killSprite', 'c1', 'c1')]
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c1')]
# 	relevantRules [('killSprite', 'c1', 'c1')]
# -----> SUBTRACE (None, {}, [('killSprite', 'DARKBLUE', 'BLUE')]) | likelihood 1.0
#
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c1')]
# 	relevantRules [('killSprite', 'c1', 'c1')]
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c1')]
# 	relevantRules [('killSprite', 'c1', 'c1')]
# 2 hypotheses:
# _______
#
# InteractionSet:
# killSprite c1 c1
#
# Class assignments:
# {'c1': ['DARKBLUE', 'BLUE']}
#
# _______
#
# InteractionSet:
# killSprite c1 c2
#
# Class assignments:
# {'c2': ['BLUE'], 'c1': ['DARKBLUE']}
#
# ___________________________________________________________________
#
# explaining events [('collectResource', 'DARKBLUE', 'RED'), ('killSprite', 'DARKBLUE', 'RED')]
# ___________________________________________________________________
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# ****>>> events in timestep False| predictions False
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# ****>>> events in timestep False| predictions False
# Will add a rule.
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1')]
# 	relevantRules [('killSprite', 'c1', 'c1'), ('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1'), ('collectResource', 'c1', 'c1')]
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1')]
# 	relevantRules [('killSprite', 'c1', 'c1'), ('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1'), ('collectResource', 'c1', 'c1')]
# Event is explained...no need to add anything.
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2')]
# 	relevantRules [('collectResource', 'c1', 'c2'), ('collectResource', 'c1', 'c2')]
# ****>>> events in timestep False| predictions True
# Will add a rule.
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# ****>>> events in timestep False| predictions False
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# ****>>> events in timestep False| predictions False
# Will add a rule.
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2'), ('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2'), ('collectResource', 'c1', 'c2')]
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2'), ('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2'), ('collectResource', 'c1', 'c2')]
# Event is explained...no need to add anything.
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1')]
# 	relevantRules [('collectResource', 'c1', 'c1'), ('collectResource', 'c1', 'c1')]
# ****>>> events in timestep False| predictions True
# Will add a rule.
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c3'), ('killSprite', 'c1', 'c3')]
# 	relevantRules [('collectResource', 'c1', 'c3'), ('collectResource', 'c1', 'c3')]
# ****>>> events in timestep False| predictions True
# Will add a rule.
# Going to clean hypothesis space!
# _______
#
# InteractionSet:
# killSprite c1 c2
# collectResource c1 c1
# killSprite c1 c1
#
# Class assignments:
# {'c2': ['BLUE'], 'c1': ['DARKBLUE', 'RED']}
#
# (None, {}, [('killSprite', 'DARKBLUE', 'BLUE')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2')]
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2')]
# -----> SUBTRACE (None, {}, [('killSprite', 'DARKBLUE', 'BLUE')]) | likelihood 1.0
#
# (None, {'trap': 1}, [('collectResource', 'DARKBLUE', 'RED'), ('killSprite', 'DARKBLUE', 'RED')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1')]
# 	relevantRules [('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1'), ('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1')]
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1')]
# 	relevantRules [('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1'), ('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1')]
# -----> SUBTRACE (None, {'trap': 1}, [('collectResource', 'DARKBLUE', 'RED'), ('killSprite', 'DARKBLUE', 'RED')]) | likelihood 1.0
#
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2')]
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2')]
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1')]
# 	relevantRules [('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1'), ('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1')]
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1')]
# 	relevantRules [('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1'), ('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1')]
# _______
#
# InteractionSet:
# killSprite c1 c1
# collectResource c1 c2
# killSprite c1 c2
#
# Class assignments:
# {'c2': ['RED'], 'c1': ['DARKBLUE', 'BLUE']}
#
# (None, {}, [('killSprite', 'DARKBLUE', 'BLUE')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c1')]
# 	relevantRules [('killSprite', 'c1', 'c1')]
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c1')]
# 	relevantRules [('killSprite', 'c1', 'c1')]
# -----> SUBTRACE (None, {}, [('killSprite', 'DARKBLUE', 'BLUE')]) | likelihood 1.0
#
# (None, {'trap': 1}, [('collectResource', 'DARKBLUE', 'RED'), ('killSprite', 'DARKBLUE', 'RED')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2')]
# 	relevantRules [('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2'), ('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2')]
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2')]
# 	relevantRules [('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2'), ('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2')]
# -----> SUBTRACE (None, {'trap': 1}, [('collectResource', 'DARKBLUE', 'RED'), ('killSprite', 'DARKBLUE', 'RED')]) | likelihood 1.0
#
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c1')]
# 	relevantRules [('killSprite', 'c1', 'c1')]
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c1')]
# 	relevantRules [('killSprite', 'c1', 'c1')]
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2')]
# 	relevantRules [('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2'), ('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2')]
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2')]
# 	relevantRules [('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2'), ('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2')]
# _______
#
# InteractionSet:
# killSprite c1 c1
# collectResource c1 c1
#
# Class assignments:
# {'c1': ['DARKBLUE', 'BLUE', 'RED']}
#
# (None, {}, [('killSprite', 'DARKBLUE', 'BLUE')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c1')]
# 	relevantRules [('killSprite', 'c1', 'c1'), ('collectResource', 'c1', 'c1')]
# ****>>> events in timestep True| predictions False
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c1')]
# 	relevantRules [('killSprite', 'c1', 'c1'), ('collectResource', 'c1', 'c1')]
# -----> SUBTRACE (None, {}, [('killSprite', 'DARKBLUE', 'BLUE')]) | likelihood 0.0
#
# (None, {'trap': 1}, [('collectResource', 'DARKBLUE', 'RED'), ('killSprite', 'DARKBLUE', 'RED')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1')]
# 	relevantRules [('killSprite', 'c1', 'c1'), ('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1'), ('collectResource', 'c1', 'c1')]
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1')]
# 	relevantRules [('killSprite', 'c1', 'c1'), ('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1'), ('collectResource', 'c1', 'c1')]
# -----> SUBTRACE (None, {'trap': 1}, [('collectResource', 'DARKBLUE', 'RED'), ('killSprite', 'DARKBLUE', 'RED')]) | likelihood 1.0
#
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c1')]
# 	relevantRules [('killSprite', 'c1', 'c1'), ('collectResource', 'c1', 'c1')]
# ****>>> events in timestep True| predictions False
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c1')]
# 	relevantRules [('killSprite', 'c1', 'c1'), ('collectResource', 'c1', 'c1')]
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1')]
# 	relevantRules [('killSprite', 'c1', 'c1'), ('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1'), ('collectResource', 'c1', 'c1')]
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1')]
# 	relevantRules [('killSprite', 'c1', 'c1'), ('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1'), ('collectResource', 'c1', 'c1')]
# _______
#
# InteractionSet:
# killSprite c1 c2
# collectResource c1 c2
#
# Class assignments:
# {'c2': ['BLUE', 'RED'], 'c1': ['DARKBLUE']}
#
# (None, {}, [('killSprite', 'DARKBLUE', 'BLUE')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2'), ('collectResource', 'c1', 'c2')]
# ****>>> events in timestep True| predictions False
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2'), ('collectResource', 'c1', 'c2')]
# -----> SUBTRACE (None, {}, [('killSprite', 'DARKBLUE', 'BLUE')]) | likelihood 0.0
#
# (None, {'trap': 1}, [('collectResource', 'DARKBLUE', 'RED'), ('killSprite', 'DARKBLUE', 'RED')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2'), ('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2'), ('collectResource', 'c1', 'c2')]
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2'), ('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2'), ('collectResource', 'c1', 'c2')]
# -----> SUBTRACE (None, {'trap': 1}, [('collectResource', 'DARKBLUE', 'RED'), ('killSprite', 'DARKBLUE', 'RED')]) | likelihood 1.0
#
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2'), ('collectResource', 'c1', 'c2')]
# ****>>> events in timestep True| predictions False
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2'), ('collectResource', 'c1', 'c2')]
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2'), ('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2'), ('collectResource', 'c1', 'c2')]
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2'), ('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2'), ('collectResource', 'c1', 'c2')]
# _______
#
# InteractionSet:
# killSprite c1 c2
# collectResource c1 c3
# killSprite c1 c3
#
# Class assignments:
# {'c3': ['RED'], 'c2': ['BLUE'], 'c1': ['DARKBLUE']}
#
# (None, {}, [('killSprite', 'DARKBLUE', 'BLUE')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2')]
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2')]
# -----> SUBTRACE (None, {}, [('killSprite', 'DARKBLUE', 'BLUE')]) | likelihood 1.0
#
# (None, {'trap': 1}, [('collectResource', 'DARKBLUE', 'RED'), ('killSprite', 'DARKBLUE', 'RED')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c3'), ('killSprite', 'c1', 'c3')]
# 	relevantRules [('collectResource', 'c1', 'c3'), ('killSprite', 'c1', 'c3'), ('collectResource', 'c1', 'c3'), ('killSprite', 'c1', 'c3')]
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c3'), ('killSprite', 'c1', 'c3')]
# 	relevantRules [('collectResource', 'c1', 'c3'), ('killSprite', 'c1', 'c3'), ('collectResource', 'c1', 'c3'), ('killSprite', 'c1', 'c3')]
# -----> SUBTRACE (None, {'trap': 1}, [('collectResource', 'DARKBLUE', 'RED'), ('killSprite', 'DARKBLUE', 'RED')]) | likelihood 1.0
#
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2')]
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2')]
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c3'), ('killSprite', 'c1', 'c3')]
# 	relevantRules [('collectResource', 'c1', 'c3'), ('killSprite', 'c1', 'c3'), ('collectResource', 'c1', 'c3'), ('killSprite', 'c1', 'c3')]
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c3'), ('killSprite', 'c1', 'c3')]
# 	relevantRules [('collectResource', 'c1', 'c3'), ('killSprite', 'c1', 'c3'), ('collectResource', 'c1', 'c3'), ('killSprite', 'c1', 'c3')]
# _______
#
# InteractionSet:
# killSprite c1 c1
#
# Class assignments:
# {'c1': ['DARKBLUE', 'BLUE']}
#
# (None, {}, [('killSprite', 'DARKBLUE', 'BLUE')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c1')]
# 	relevantRules [('killSprite', 'c1', 'c1')]
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c1')]
# 	relevantRules [('killSprite', 'c1', 'c1')]
# -----> SUBTRACE (None, {}, [('killSprite', 'DARKBLUE', 'BLUE')]) | likelihood 1.0
#
# (None, {'trap': 1}, [('collectResource', 'DARKBLUE', 'RED'), ('killSprite', 'DARKBLUE', 'RED')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# ****>>> events in timestep False| predictions False
# -----> SUBTRACE (None, {'trap': 1}, [('collectResource', 'DARKBLUE', 'RED'), ('killSprite', 'DARKBLUE', 'RED')]) | likelihood 0.0
#
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c1')]
# 	relevantRules [('killSprite', 'c1', 'c1')]
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c1')]
# 	relevantRules [('killSprite', 'c1', 'c1')]
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# ****>>> events in timestep False| predictions False
# _______
#
# InteractionSet:
# killSprite c1 c2
#
# Class assignments:
# {'c2': ['BLUE'], 'c1': ['DARKBLUE']}
#
# (None, {}, [('killSprite', 'DARKBLUE', 'BLUE')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2')]
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2')]
# -----> SUBTRACE (None, {}, [('killSprite', 'DARKBLUE', 'BLUE')]) | likelihood 1.0
#
# (None, {'trap': 1}, [('collectResource', 'DARKBLUE', 'RED'), ('killSprite', 'DARKBLUE', 'RED')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# ****>>> events in timestep False| predictions False
# -----> SUBTRACE (None, {'trap': 1}, [('collectResource', 'DARKBLUE', 'RED'), ('killSprite', 'DARKBLUE', 'RED')]) | likelihood 0.0
#
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2')]
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2')]
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# ****>>> events in timestep False| predictions False
# 3 hypotheses:
# _______
#
# InteractionSet:
# killSprite c1 c2
# collectResource c1 c1
# killSprite c1 c1
#
# Class assignments:
# {'c2': ['BLUE'], 'c1': ['DARKBLUE', 'RED']}
#
# _______
#
# InteractionSet:
# killSprite c1 c1
# collectResource c1 c2
# killSprite c1 c2
#
# Class assignments:
# {'c2': ['RED'], 'c1': ['DARKBLUE', 'BLUE']}
#
# _______
#
# InteractionSet:
# killSprite c1 c2
# collectResource c1 c3
# killSprite c1 c3
#
# Class assignments:
# {'c3': ['RED'], 'c2': ['BLUE'], 'c1': ['DARKBLUE']}
#
# ___________________________________________________________________
#
# explaining events [('bounceForward', 'DARKBLUE', 'BLUE')]
# ___________________________________________________________________
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('bounceForward', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2')]
# ****>>> events in timestep False| predictions False
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('bounceForward', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2')]
# ****>>> events in timestep False| predictions False
# Will add a precondition.
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('bounceForward', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2')]
# ****>>> events in timestep False| predictions False
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('bounceForward', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2')]
# ****>>> events in timestep False| predictions False
# Will add a precondition.
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('bounceForward', 'c1', 'c1')]
# 	relevantRules [('killSprite', 'c1', 'c1')]
# ****>>> events in timestep False| predictions False
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('bounceForward', 'c1', 'c1')]
# 	relevantRules [('killSprite', 'c1', 'c1')]
# ****>>> events in timestep False| predictions False
# Will add a precondition.
# Going to clean hypothesis space!
# _______
#
# InteractionSet:
# killSprite c1 c2 ['not trap>0']
# collectResource c1 c1
# killSprite c1 c1
#
# Class assignments:
# {'c2': ['BLUE'], 'c1': ['DARKBLUE', 'RED']}
#
# (None, {}, [('killSprite', 'DARKBLUE', 'BLUE')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2')]
# 	rule has preconditions and they are  True
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2')]
# 	rule has preconditions and they are  True
# -----> SUBTRACE (None, {}, [('killSprite', 'DARKBLUE', 'BLUE')]) | likelihood 1.0
#
# (None, {'trap': 1}, [('collectResource', 'DARKBLUE', 'RED'), ('killSprite', 'DARKBLUE', 'RED')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1')]
# 	relevantRules [('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1'), ('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1')]
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1')]
# 	relevantRules [('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1'), ('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1')]
# -----> SUBTRACE (None, {'trap': 1}, [('collectResource', 'DARKBLUE', 'RED'), ('killSprite', 'DARKBLUE', 'RED')]) | likelihood 1.0
#
# (None, {'trap': 1}, [('bounceForward', 'DARKBLUE', 'BLUE')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('bounceForward', 'c1', 'c2')]
# 	relevantRules []
# ****>>> events in timestep False| predictions True
# -----> SUBTRACE (None, {'trap': 1}, [('bounceForward', 'DARKBLUE', 'BLUE')]) | likelihood 0.0
#
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2')]
# 	rule has preconditions and they are  True
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2')]
# 	rule has preconditions and they are  True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1')]
# 	relevantRules [('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1'), ('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1')]
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1')]
# 	relevantRules [('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1'), ('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1')]
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('bounceForward', 'c1', 'c2')]
# 	relevantRules []
# ****>>> events in timestep False| predictions True
# _______
#
# InteractionSet:
# killSprite c1 c2 ['not trap>0']
# collectResource c1 c1
# killSprite c1 c1
# bounceForward c1 c2 ['trap>0']
#
# Class assignments:
# {'c2': ['BLUE'], 'c1': ['DARKBLUE', 'RED']}
#
# (None, {}, [('killSprite', 'DARKBLUE', 'BLUE')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2'), ('bounceForward', 'c1', 'c2')]
# 	rule has preconditions and they are  True
# 	rule has preconditions and they are  True
# ****>>> events in timestep True| predictions False
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2'), ('bounceForward', 'c1', 'c2')]
# 	rule has preconditions and they are  True
# 	rule has preconditions and they are  True
# -----> SUBTRACE (None, {}, [('killSprite', 'DARKBLUE', 'BLUE')]) | likelihood 0.0
#
# (None, {'trap': 1}, [('collectResource', 'DARKBLUE', 'RED'), ('killSprite', 'DARKBLUE', 'RED')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1')]
# 	relevantRules [('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1'), ('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1')]
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1')]
# 	relevantRules [('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1'), ('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1')]
# -----> SUBTRACE (None, {'trap': 1}, [('collectResource', 'DARKBLUE', 'RED'), ('killSprite', 'DARKBLUE', 'RED')]) | likelihood 1.0
#
# (None, {'trap': 1}, [('bounceForward', 'DARKBLUE', 'BLUE')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('bounceForward', 'c1', 'c2')]
# 	relevantRules [('bounceForward', 'c1', 'c2')]
# 	rule has preconditions and they are  True
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('bounceForward', 'c1', 'c2')]
# 	relevantRules [('bounceForward', 'c1', 'c2')]
# 	rule has preconditions and they are  True
# -----> SUBTRACE (None, {'trap': 1}, [('bounceForward', 'DARKBLUE', 'BLUE')]) | likelihood 1.0
#
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2'), ('bounceForward', 'c1', 'c2')]
# 	rule has preconditions and they are  True
# 	rule has preconditions and they are  True
# ****>>> events in timestep True| predictions False
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2'), ('bounceForward', 'c1', 'c2')]
# 	rule has preconditions and they are  True
# 	rule has preconditions and they are  True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1')]
# 	relevantRules [('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1'), ('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1')]
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1')]
# 	relevantRules [('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1'), ('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1')]
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('bounceForward', 'c1', 'c2')]
# 	relevantRules [('bounceForward', 'c1', 'c2')]
# 	rule has preconditions and they are  True
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('bounceForward', 'c1', 'c2')]
# 	relevantRules [('bounceForward', 'c1', 'c2')]
# 	rule has preconditions and they are  True
# _______
#
# InteractionSet:
# killSprite c1 c1 ['not trap>0']
# collectResource c1 c2
# killSprite c1 c2
#
# Class assignments:
# {'c2': ['RED'], 'c1': ['DARKBLUE', 'BLUE']}
#
# (None, {}, [('killSprite', 'DARKBLUE', 'BLUE')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c1')]
# 	relevantRules [('killSprite', 'c1', 'c1')]
# 	rule has preconditions and they are  True
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c1')]
# 	relevantRules [('killSprite', 'c1', 'c1')]
# 	rule has preconditions and they are  True
# -----> SUBTRACE (None, {}, [('killSprite', 'DARKBLUE', 'BLUE')]) | likelihood 1.0
#
# (None, {'trap': 1}, [('collectResource', 'DARKBLUE', 'RED'), ('killSprite', 'DARKBLUE', 'RED')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2')]
# 	relevantRules [('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2'), ('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2')]
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2')]
# 	relevantRules [('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2'), ('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2')]
# -----> SUBTRACE (None, {'trap': 1}, [('collectResource', 'DARKBLUE', 'RED'), ('killSprite', 'DARKBLUE', 'RED')]) | likelihood 1.0
#
# (None, {'trap': 1}, [('bounceForward', 'DARKBLUE', 'BLUE')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('bounceForward', 'c1', 'c1')]
# 	relevantRules []
# ****>>> events in timestep False| predictions True
# -----> SUBTRACE (None, {'trap': 1}, [('bounceForward', 'DARKBLUE', 'BLUE')]) | likelihood 0.0
#
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c1')]
# 	relevantRules [('killSprite', 'c1', 'c1')]
# 	rule has preconditions and they are  True
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c1')]
# 	relevantRules [('killSprite', 'c1', 'c1')]
# 	rule has preconditions and they are  True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2')]
# 	relevantRules [('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2'), ('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2')]
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2')]
# 	relevantRules [('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2'), ('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2')]
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('bounceForward', 'c1', 'c1')]
# 	relevantRules []
# ****>>> events in timestep False| predictions True
# _______
#
# InteractionSet:
# killSprite c1 c1
# collectResource c1 c1
#
# Class assignments:
# {'c1': ['DARKBLUE', 'BLUE', 'RED']}
#
# (None, {}, [('killSprite', 'DARKBLUE', 'BLUE')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c1')]
# 	relevantRules [('killSprite', 'c1', 'c1'), ('collectResource', 'c1', 'c1')]
# ****>>> events in timestep True| predictions False
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c1')]
# 	relevantRules [('killSprite', 'c1', 'c1'), ('collectResource', 'c1', 'c1')]
# -----> SUBTRACE (None, {}, [('killSprite', 'DARKBLUE', 'BLUE')]) | likelihood 0.0
#
# (None, {'trap': 1}, [('collectResource', 'DARKBLUE', 'RED'), ('killSprite', 'DARKBLUE', 'RED')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1')]
# 	relevantRules [('killSprite', 'c1', 'c1'), ('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1'), ('collectResource', 'c1', 'c1')]
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1')]
# 	relevantRules [('killSprite', 'c1', 'c1'), ('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1'), ('collectResource', 'c1', 'c1')]
# -----> SUBTRACE (None, {'trap': 1}, [('collectResource', 'DARKBLUE', 'RED'), ('killSprite', 'DARKBLUE', 'RED')]) | likelihood 1.0
#
# (None, {'trap': 1}, [('bounceForward', 'DARKBLUE', 'BLUE')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('bounceForward', 'c1', 'c1')]
# 	relevantRules [('killSprite', 'c1', 'c1'), ('collectResource', 'c1', 'c1')]
# ****>>> events in timestep False| predictions False
# -----> SUBTRACE (None, {'trap': 1}, [('bounceForward', 'DARKBLUE', 'BLUE')]) | likelihood 0.0
#
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c1')]
# 	relevantRules [('killSprite', 'c1', 'c1'), ('collectResource', 'c1', 'c1')]
# ****>>> events in timestep True| predictions False
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c1')]
# 	relevantRules [('killSprite', 'c1', 'c1'), ('collectResource', 'c1', 'c1')]
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1')]
# 	relevantRules [('killSprite', 'c1', 'c1'), ('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1'), ('collectResource', 'c1', 'c1')]
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1')]
# 	relevantRules [('killSprite', 'c1', 'c1'), ('collectResource', 'c1', 'c1'), ('killSprite', 'c1', 'c1'), ('collectResource', 'c1', 'c1')]
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('bounceForward', 'c1', 'c1')]
# 	relevantRules [('killSprite', 'c1', 'c1'), ('collectResource', 'c1', 'c1')]
# ****>>> events in timestep False| predictions False
# _______
#
# InteractionSet:
# killSprite c1 c2
#
# Class assignments:
# {'c2': ['BLUE'], 'c1': ['DARKBLUE']}
#
# (None, {}, [('killSprite', 'DARKBLUE', 'BLUE')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2')]
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2')]
# -----> SUBTRACE (None, {}, [('killSprite', 'DARKBLUE', 'BLUE')]) | likelihood 1.0
#
# (None, {'trap': 1}, [('collectResource', 'DARKBLUE', 'RED'), ('killSprite', 'DARKBLUE', 'RED')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# ****>>> events in timestep False| predictions False
# -----> SUBTRACE (None, {'trap': 1}, [('collectResource', 'DARKBLUE', 'RED'), ('killSprite', 'DARKBLUE', 'RED')]) | likelihood 0.0
#
# (None, {'trap': 1}, [('bounceForward', 'DARKBLUE', 'BLUE')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('bounceForward', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2')]
# ****>>> events in timestep False| predictions False
# -----> SUBTRACE (None, {'trap': 1}, [('bounceForward', 'DARKBLUE', 'BLUE')]) | likelihood 0.0
#
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2')]
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2')]
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# ****>>> events in timestep False| predictions False
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('bounceForward', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2')]
# ****>>> events in timestep False| predictions False
# _______
#
# InteractionSet:
# killSprite c1 c2
# collectResource c1 c2
#
# Class assignments:
# {'c2': ['BLUE', 'RED'], 'c1': ['DARKBLUE']}
#
# (None, {}, [('killSprite', 'DARKBLUE', 'BLUE')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2'), ('collectResource', 'c1', 'c2')]
# ****>>> events in timestep True| predictions False
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2'), ('collectResource', 'c1', 'c2')]
# -----> SUBTRACE (None, {}, [('killSprite', 'DARKBLUE', 'BLUE')]) | likelihood 0.0
#
# (None, {'trap': 1}, [('collectResource', 'DARKBLUE', 'RED'), ('killSprite', 'DARKBLUE', 'RED')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2'), ('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2'), ('collectResource', 'c1', 'c2')]
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2'), ('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2'), ('collectResource', 'c1', 'c2')]
# -----> SUBTRACE (None, {'trap': 1}, [('collectResource', 'DARKBLUE', 'RED'), ('killSprite', 'DARKBLUE', 'RED')]) | likelihood 1.0
#
# (None, {'trap': 1}, [('bounceForward', 'DARKBLUE', 'BLUE')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('bounceForward', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2'), ('collectResource', 'c1', 'c2')]
# ****>>> events in timestep False| predictions False
# -----> SUBTRACE (None, {'trap': 1}, [('bounceForward', 'DARKBLUE', 'BLUE')]) | likelihood 0.0
#
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2'), ('collectResource', 'c1', 'c2')]
# ****>>> events in timestep True| predictions False
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2'), ('collectResource', 'c1', 'c2')]
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2'), ('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2'), ('collectResource', 'c1', 'c2')]
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2'), ('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2'), ('collectResource', 'c1', 'c2')]
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('bounceForward', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2'), ('collectResource', 'c1', 'c2')]
# ****>>> events in timestep False| predictions False
# _______
#
# InteractionSet:
# killSprite c1 c1 ['not trap>0']
# collectResource c1 c2
# killSprite c1 c2
# bounceForward c1 c1 ['trap>0']
#
# Class assignments:
# {'c2': ['RED'], 'c1': ['DARKBLUE', 'BLUE']}
#
# (None, {}, [('killSprite', 'DARKBLUE', 'BLUE')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c1')]
# 	relevantRules [('killSprite', 'c1', 'c1'), ('bounceForward', 'c1', 'c1')]
# 	rule has preconditions and they are  True
# 	rule has preconditions and they are  True
# ****>>> events in timestep True| predictions False
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c1')]
# 	relevantRules [('killSprite', 'c1', 'c1'), ('bounceForward', 'c1', 'c1')]
# 	rule has preconditions and they are  True
# 	rule has preconditions and they are  True
# -----> SUBTRACE (None, {}, [('killSprite', 'DARKBLUE', 'BLUE')]) | likelihood 0.0
#
# (None, {'trap': 1}, [('collectResource', 'DARKBLUE', 'RED'), ('killSprite', 'DARKBLUE', 'RED')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2')]
# 	relevantRules [('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2'), ('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2')]
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2')]
# 	relevantRules [('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2'), ('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2')]
# -----> SUBTRACE (None, {'trap': 1}, [('collectResource', 'DARKBLUE', 'RED'), ('killSprite', 'DARKBLUE', 'RED')]) | likelihood 1.0
#
# (None, {'trap': 1}, [('bounceForward', 'DARKBLUE', 'BLUE')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('bounceForward', 'c1', 'c1')]
# 	relevantRules [('bounceForward', 'c1', 'c1')]
# 	rule has preconditions and they are  True
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('bounceForward', 'c1', 'c1')]
# 	relevantRules [('bounceForward', 'c1', 'c1')]
# 	rule has preconditions and they are  True
# -----> SUBTRACE (None, {'trap': 1}, [('bounceForward', 'DARKBLUE', 'BLUE')]) | likelihood 1.0
#
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c1')]
# 	relevantRules [('killSprite', 'c1', 'c1'), ('bounceForward', 'c1', 'c1')]
# 	rule has preconditions and they are  True
# 	rule has preconditions and they are  True
# ****>>> events in timestep True| predictions False
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c1')]
# 	relevantRules [('killSprite', 'c1', 'c1'), ('bounceForward', 'c1', 'c1')]
# 	rule has preconditions and they are  True
# 	rule has preconditions and they are  True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2')]
# 	relevantRules [('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2'), ('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2')]
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2')]
# 	relevantRules [('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2'), ('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2')]
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('bounceForward', 'c1', 'c1')]
# 	relevantRules [('bounceForward', 'c1', 'c1')]
# 	rule has preconditions and they are  True
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('bounceForward', 'c1', 'c1')]
# 	relevantRules [('bounceForward', 'c1', 'c1')]
# 	rule has preconditions and they are  True
# _______
#
# InteractionSet:
# killSprite c1 c1
#
# Class assignments:
# {'c1': ['DARKBLUE', 'BLUE']}
#
# (None, {}, [('killSprite', 'DARKBLUE', 'BLUE')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c1')]
# 	relevantRules [('killSprite', 'c1', 'c1')]
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c1')]
# 	relevantRules [('killSprite', 'c1', 'c1')]
# -----> SUBTRACE (None, {}, [('killSprite', 'DARKBLUE', 'BLUE')]) | likelihood 1.0
#
# (None, {'trap': 1}, [('collectResource', 'DARKBLUE', 'RED'), ('killSprite', 'DARKBLUE', 'RED')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# ****>>> events in timestep False| predictions False
# -----> SUBTRACE (None, {'trap': 1}, [('collectResource', 'DARKBLUE', 'RED'), ('killSprite', 'DARKBLUE', 'RED')]) | likelihood 0.0
#
# (None, {'trap': 1}, [('bounceForward', 'DARKBLUE', 'BLUE')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('bounceForward', 'c1', 'c1')]
# 	relevantRules [('killSprite', 'c1', 'c1')]
# ****>>> events in timestep False| predictions False
# -----> SUBTRACE (None, {'trap': 1}, [('bounceForward', 'DARKBLUE', 'BLUE')]) | likelihood 0.0
#
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c1')]
# 	relevantRules [('killSprite', 'c1', 'c1')]
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c1')]
# 	relevantRules [('killSprite', 'c1', 'c1')]
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# ****>>> events in timestep False| predictions False
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('bounceForward', 'c1', 'c1')]
# 	relevantRules [('killSprite', 'c1', 'c1')]
# ****>>> events in timestep False| predictions False
# _______
#
# InteractionSet:
# killSprite c1 c2 ['not trap>0']
# collectResource c1 c3
# killSprite c1 c3
#
# Class assignments:
# ...
# ****>>> events in timestep False| predictions False
# -----> SUBTRACE (None, {'trap': 1}, [('killSprite', 'DARKBLUE', 'GOLD')]) | likelihood 0.0
#
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2'), ('collectResource', 'c1', 'c2')]
# ****>>> events in timestep True| predictions False
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2'), ('collectResource', 'c1', 'c2')]
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2'), ('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2'), ('collectResource', 'c1', 'c2')]
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2'), ('collectResource', 'c1', 'c2'), ('killSprite', 'c1', 'c2'), ('collectResource', 'c1', 'c2')]
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('bounceForward', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2'), ('collectResource', 'c1', 'c2')]
# ****>>> events in timestep False| predictions False
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# ****>>> events in timestep False| predictions False
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# ****>>> events in timestep False| predictions False
# _______
#
# InteractionSet:
# killSprite c1 c2 ['not trap>0']
# collectResource c1 c3
# killSprite c1 c3
#
# Class assignments:
# {'c3': ['RED'], 'c2': ['BLUE'], 'c1': ['DARKBLUE']}
#
# (None, {}, [('killSprite', 'DARKBLUE', 'BLUE')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2')]
# 	rule has preconditions and they are  True
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2')]
# 	rule has preconditions and they are  True
# -----> SUBTRACE (None, {}, [('killSprite', 'DARKBLUE', 'BLUE')]) | likelihood 1.0
#
# (None, {'trap': 1}, [('collectResource', 'DARKBLUE', 'RED'), ('killSprite', 'DARKBLUE', 'RED')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c3'), ('killSprite', 'c1', 'c3')]
# 	relevantRules [('collectResource', 'c1', 'c3'), ('killSprite', 'c1', 'c3'), ('collectResource', 'c1', 'c3'), ('killSprite', 'c1', 'c3')]
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c3'), ('killSprite', 'c1', 'c3')]
# 	relevantRules [('collectResource', 'c1', 'c3'), ('killSprite', 'c1', 'c3'), ('collectResource', 'c1', 'c3'), ('killSprite', 'c1', 'c3')]
# -----> SUBTRACE (None, {'trap': 1}, [('collectResource', 'DARKBLUE', 'RED'), ('killSprite', 'DARKBLUE', 'RED')]) | likelihood 1.0
#
# (None, {'trap': 1}, [('bounceForward', 'DARKBLUE', 'BLUE')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('bounceForward', 'c1', 'c2')]
# 	relevantRules []
# ****>>> events in timestep False| predictions True
# -----> SUBTRACE (None, {'trap': 1}, [('bounceForward', 'DARKBLUE', 'BLUE')]) | likelihood 0.0
#
# (None, {'trap': 1}, [('bounceForward', 'DARKBLUE', 'ORANGE')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# ****>>> events in timestep False| predictions False
# -----> SUBTRACE (None, {'trap': 1}, [('bounceForward', 'DARKBLUE', 'ORANGE')]) | likelihood 0.0
#
# (None, {'trap': 1}, [('killSprite', 'DARKBLUE', 'GOLD')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# ****>>> events in timestep False| predictions False
# -----> SUBTRACE (None, {'trap': 1}, [('killSprite', 'DARKBLUE', 'GOLD')]) | likelihood 0.0
#
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2')]
# 	rule has preconditions and they are  True
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2')]
# 	rule has preconditions and they are  True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c3'), ('killSprite', 'c1', 'c3')]
# 	relevantRules [('collectResource', 'c1', 'c3'), ('killSprite', 'c1', 'c3'), ('collectResource', 'c1', 'c3'), ('killSprite', 'c1', 'c3')]
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c3'), ('killSprite', 'c1', 'c3')]
# 	relevantRules [('collectResource', 'c1', 'c3'), ('killSprite', 'c1', 'c3'), ('collectResource', 'c1', 'c3'), ('killSprite', 'c1', 'c3')]
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('bounceForward', 'c1', 'c2')]
# 	relevantRules []
# ****>>> events in timestep False| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# ****>>> events in timestep False| predictions False
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# ****>>> events in timestep False| predictions False
# _______
#
# InteractionSet:
# killSprite c1 c1
#
# Class assignments:
# {'c1': ['DARKBLUE', 'BLUE']}
#
# (None, {}, [('killSprite', 'DARKBLUE', 'BLUE')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c1')]
# 	relevantRules [('killSprite', 'c1', 'c1')]
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c1')]
# 	relevantRules [('killSprite', 'c1', 'c1')]
# -----> SUBTRACE (None, {}, [('killSprite', 'DARKBLUE', 'BLUE')]) | likelihood 1.0
#
# (None, {'trap': 1}, [('collectResource', 'DARKBLUE', 'RED'), ('killSprite', 'DARKBLUE', 'RED')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# ****>>> events in timestep False| predictions False
# -----> SUBTRACE (None, {'trap': 1}, [('collectResource', 'DARKBLUE', 'RED'), ('killSprite', 'DARKBLUE', 'RED')]) | likelihood 0.0
#
# (None, {'trap': 1}, [('bounceForward', 'DARKBLUE', 'BLUE')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('bounceForward', 'c1', 'c1')]
# 	relevantRules [('killSprite', 'c1', 'c1')]
# ****>>> events in timestep False| predictions False
# -----> SUBTRACE (None, {'trap': 1}, [('bounceForward', 'DARKBLUE', 'BLUE')]) | likelihood 0.0
#
# (None, {'trap': 1}, [('bounceForward', 'DARKBLUE', 'ORANGE')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# ****>>> events in timestep False| predictions False
# -----> SUBTRACE (None, {'trap': 1}, [('bounceForward', 'DARKBLUE', 'ORANGE')]) | likelihood 0.0
#
# (None, {'trap': 1}, [('killSprite', 'DARKBLUE', 'GOLD')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# ****>>> events in timestep False| predictions False
# -----> SUBTRACE (None, {'trap': 1}, [('killSprite', 'DARKBLUE', 'GOLD')]) | likelihood 0.0
#
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c1')]
# 	relevantRules [('killSprite', 'c1', 'c1')]
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c1')]
# 	relevantRules [('killSprite', 'c1', 'c1')]
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# ****>>> events in timestep False| predictions False
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('bounceForward', 'c1', 'c1')]
# 	relevantRules [('killSprite', 'c1', 'c1')]
# ****>>> events in timestep False| predictions False
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# ****>>> events in timestep False| predictions False
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# ****>>> events in timestep False| predictions False
# _______
#
# InteractionSet:
# killSprite c1 c2
#
# Class assignments:
# {'c2': ['BLUE'], 'c1': ['DARKBLUE']}
#
# (None, {}, [('killSprite', 'DARKBLUE', 'BLUE')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2')]
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2')]
# -----> SUBTRACE (None, {}, [('killSprite', 'DARKBLUE', 'BLUE')]) | likelihood 1.0
#
# (None, {'trap': 1}, [('collectResource', 'DARKBLUE', 'RED'), ('killSprite', 'DARKBLUE', 'RED')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# ****>>> events in timestep False| predictions False
# -----> SUBTRACE (None, {'trap': 1}, [('collectResource', 'DARKBLUE', 'RED'), ('killSprite', 'DARKBLUE', 'RED')]) | likelihood 0.0
#
# (None, {'trap': 1}, [('bounceForward', 'DARKBLUE', 'BLUE')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('bounceForward', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2')]
# ****>>> events in timestep False| predictions False
# -----> SUBTRACE (None, {'trap': 1}, [('bounceForward', 'DARKBLUE', 'BLUE')]) | likelihood 0.0
#
# (None, {'trap': 1}, [('bounceForward', 'DARKBLUE', 'ORANGE')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# ****>>> events in timestep False| predictions False
# -----> SUBTRACE (None, {'trap': 1}, [('bounceForward', 'DARKBLUE', 'ORANGE')]) | likelihood 0.0
#
# (None, {'trap': 1}, [('killSprite', 'DARKBLUE', 'GOLD')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# ****>>> events in timestep False| predictions False
# -----> SUBTRACE (None, {'trap': 1}, [('killSprite', 'DARKBLUE', 'GOLD')]) | likelihood 0.0
#
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2')]
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2')]
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# ****>>> events in timestep False| predictions False
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('bounceForward', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2')]
# ****>>> events in timestep False| predictions False
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# ****>>> events in timestep False| predictions False
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# ****>>> events in timestep False| predictions False
# _______
#
# InteractionSet:
# killSprite c1 c2 ['not trap>0']
# collectResource c1 c3
# killSprite c1 c3
# bounceForward c1 c2 ['trap>0']
#
# Class assignments:
# {'c3': ['RED'], 'c2': ['BLUE'], 'c1': ['DARKBLUE']}
#
# (None, {}, [('killSprite', 'DARKBLUE', 'BLUE')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2'), ('bounceForward', 'c1', 'c2')]
# 	rule has preconditions and they are  True
# 	rule has preconditions and they are  True
# ****>>> events in timestep True| predictions False
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2'), ('bounceForward', 'c1', 'c2')]
# 	rule has preconditions and they are  True
# 	rule has preconditions and they are  True
# -----> SUBTRACE (None, {}, [('killSprite', 'DARKBLUE', 'BLUE')]) | likelihood 0.0
#
# (None, {'trap': 1}, [('collectResource', 'DARKBLUE', 'RED'), ('killSprite', 'DARKBLUE', 'RED')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c3'), ('killSprite', 'c1', 'c3')]
# 	relevantRules [('collectResource', 'c1', 'c3'), ('killSprite', 'c1', 'c3'), ('collectResource', 'c1', 'c3'), ('killSprite', 'c1', 'c3')]
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c3'), ('killSprite', 'c1', 'c3')]
# 	relevantRules [('collectResource', 'c1', 'c3'), ('killSprite', 'c1', 'c3'), ('collectResource', 'c1', 'c3'), ('killSprite', 'c1', 'c3')]
# -----> SUBTRACE (None, {'trap': 1}, [('collectResource', 'DARKBLUE', 'RED'), ('killSprite', 'DARKBLUE', 'RED')]) | likelihood 1.0
#
# (None, {'trap': 1}, [('bounceForward', 'DARKBLUE', 'BLUE')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('bounceForward', 'c1', 'c2')]
# 	relevantRules [('bounceForward', 'c1', 'c2')]
# 	rule has preconditions and they are  True
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('bounceForward', 'c1', 'c2')]
# 	relevantRules [('bounceForward', 'c1', 'c2')]
# 	rule has preconditions and they are  True
# -----> SUBTRACE (None, {'trap': 1}, [('bounceForward', 'DARKBLUE', 'BLUE')]) | likelihood 1.0
#
# (None, {'trap': 1}, [('bounceForward', 'DARKBLUE', 'ORANGE')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# ****>>> events in timestep False| predictions False
# -----> SUBTRACE (None, {'trap': 1}, [('bounceForward', 'DARKBLUE', 'ORANGE')]) | likelihood 0.0
#
# (None, {'trap': 1}, [('killSprite', 'DARKBLUE', 'GOLD')])
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# ****>>> events in timestep False| predictions False
# -----> SUBTRACE (None, {'trap': 1}, [('killSprite', 'DARKBLUE', 'GOLD')]) | likelihood 0.0
#
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2'), ('bounceForward', 'c1', 'c2')]
# 	rule has preconditions and they are  True
# 	rule has preconditions and they are  True
# ****>>> events in timestep True| predictions False
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('killSprite', 'c1', 'c2')]
# 	relevantRules [('killSprite', 'c1', 'c2'), ('bounceForward', 'c1', 'c2')]
# 	rule has preconditions and they are  True
# 	rule has preconditions and they are  True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c3'), ('killSprite', 'c1', 'c3')]
# 	relevantRules [('collectResource', 'c1', 'c3'), ('killSprite', 'c1', 'c3'), ('collectResource', 'c1', 'c3'), ('killSprite', 'c1', 'c3')]
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('collectResource', 'c1', 'c3'), ('killSprite', 'c1', 'c3')]
# 	relevantRules [('collectResource', 'c1', 'c3'), ('killSprite', 'c1', 'c3'), ('collectResource', 'c1', 'c3'), ('killSprite', 'c1', 'c3')]
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('bounceForward', 'c1', 'c2')]
# 	relevantRules [('bounceForward', 'c1', 'c2')]
# 	rule has preconditions and they are  True
# ****>>> events in timestep True| predictions True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# 	interpretations [('bounceForward', 'c1', 'c2')]
# 	relevantRules [('bounceForward', 'c1', 'c2')]
# 	rule has preconditions and they are  True
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# ****>>> events in timestep False| predictions False
# In checkPredictionsInTimeStep -- this is the trouble maker! >:(
# ****>>> events in timestep False| predictions False
# 0 hypotheses:
# ___________________________________________________________________

# %%
## Debugging Precondition negation

f1 = lambda x: x['trap']>0
p1 = Precondition('trap>0', f1, 'trap')
p2 = copy.deepcopy(p1)
p2.negate()

agentState = {'trap':1}
print p1.check(agentState)
print p2.check(agentState)
p1.display()
p2.display()
# Out:
# True
# False
# trap>0
# not trap>0
